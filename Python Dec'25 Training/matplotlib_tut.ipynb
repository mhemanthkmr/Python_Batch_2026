# %%
import matplotlib.pyplot as plt

# %%
x = [2,3,4,5,5,6,77,8,99,24,56,12,45,34,56,34,67,98]

# %%
plt.hist(x)
# Out:
# (array([7., 1., 1., 2., 1., 2., 1., 1., 0., 2.]),
#  array([ 2. , 11.7, 21.4, 31.1, 40.8, 50.5, 60.2, 69.9, 79.6, 89.3, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
x = ['Dals & Pulses', 'Health Care', 'Snacks', 'Beverages', 'Soaps', 'Games', 'Toys']
y = [200, 180, 120, 150, 210, 220, 240]

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 7 artists>
